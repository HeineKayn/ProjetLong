# %%
a = 15
a = str(a)
a = "0"*(4-len(a)) + a
print(a)
# Out:
# 0015

# %%
for i in reversed(range(0,5)):
    print(i)
# Out:
# 4
# 3
# 2
# 1
# 0

# %%
url = "https://samples.vx-underground.org/samples/Blocks/Virusshare%20Collection/Virusshare.00000.7z"

from urllib import request
#response = request.urlretrieve(url, "Virusshare.0001.7z")

# %%
#url = "http://samples.vx-underground.org"
params = {'Filename':"/samples/Blocks/Virusshare%20Collection/Virusshare.00000.7z"}
  
# sending get request and saving the response as response object
url = "https://samples.vx-underground.org/samples/Blocks/Virusshare%20Collection/Virusshare.00000.7z"
#r = requests.get(url = url)

# %%
import requests 
import shutil

def download_data(url,dest):
    zipname = dest + "VirusTemp.7z"
    password = "infected"
     
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(zipname, 'wb') as f:
            for i,chunk in enumerate(r.iter_content(chunk_size=8192)):  
                f.write(chunk)
                
    with py7zr.SevenZipFile(zipname, mode='r', password=password) as z: 
        z.extractall() 
        
    extracted = url.split("/")[-1]
    extracted = extracted.split(".")[:-1]
    unzipped = dest + extracted + "/"
    
    entries = os.listdir(dest)
    for entry in entries:
        filename = unzipped + entry
        fileType = subprocess.check_output(filename, shell=True).decode()
    
        folder = "other"
        if "PE" in fileType : folder = "pe"
        elif "ELF" in fileType : folder = "elf"
        elif "MS-DOS" in fileType : folder = "msdos"

        hashed = hash(extracted)
        img_path = f"{dest}{folder}/{hashed}.png"
        # convert to img
        
    os.remove(zipfile)
    shutil.rmtree(unzipped)
    
download_data(url,"../data/images")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ...
